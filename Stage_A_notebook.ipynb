# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv ("/content/FoodBalanceSheets_E_Africa_NOFLAG.csv", encoding = "latin-1")

# %%
print (df.head()) #showing the first 5 values
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
print (df.tail()) #showing the last 5 values
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit  Y2014  Y2015  \
# 60938                                    Food      1000 tonnes  42.00  46.00
# 60939     Food supply quantity (kg/capita/yr)               kg   3.06   3.33
# 60940           Food supply (kcal/capita/day)  kcal/capita/day   3.00   4.00
# 60941  Protein supply quantity (g/capita/day)     g/capita/day   0.10   0.11
# 60942      Fat supply quantity (g/capita/day)     g/capita/day   0.04   0.05
#
#        Y2016  Y2017  Y2018
# 60938  33.00  19.00  16.00
# 60939   2.35   1.33   1.08
# ...

# %%
df.isnull().sum() #checking for missing values
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
df.duplicated().any() #checking for duplicate rows
# Out:
# False

# %%
x = df.groupby('Item Code')['Item Code'].count() #group item code by its frequency and count them
print (x)
# Out:
# Item Code
# 2501     90
# 2511    653
# 2513    570
# 2514    687
# 2515    474
#        ...
# 2946    639
# 2948    631
# 2949    571
# 2960    535
# 2961    392
# Name: Item Code, Length: 122, dtype: int64

# %%
x = df.groupby('Area Code')['Area Code'].count() #group area code by its frequency and count them
print (x)
# Out:
# Area Code
# 4      1313
# 7      1424
# 20     1378
# 32     1460
# 35     1260
# 37     1344
# 39     1343
# 45       45
# 46     1413
# 53     1285
# 59     1488
# 62       39
# 72     1095
# 74     1245
# 75     1168
# 81     1354
# 90     1410
# 107    1467
# 114    1560
# 122    1150
# 123    1206
# 129    1439
# 130    1447
# 133    1293
# 136    1195
# 137    1378
# 143    1393
# 144    1427
# 147    1283
# 158    1403
# 159    1474
# 175    1128
# 181    1393
# 184    1426
# 193    1177
# 195    1462
# 196      68
# 197    1242
# 202    1399
# 206      53
# 209    1284
# 215    1419
# 217    1294
# 222    1338
# 226    1458
# 233    1409
# 238    1447
# 251    1451
# 276    1316
# Name: Area Code, dtype: int64

# %%
df.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
df['Element']
# Out:
# 0                 Total Population - Both sexes
# 1                      Domestic supply quantity
# 2                 Food supply (kcal/capita/day)
# 3        Protein supply quantity (g/capita/day)
# 4            Fat supply quantity (g/capita/day)
#                           ...
# 60938                                      Food
# 60939       Food supply quantity (kg/capita/yr)
# 60940             Food supply (kcal/capita/day)
# 60941    Protein supply quantity (g/capita/day)
# 60942        Fat supply quantity (g/capita/day)
# Name: Element, Length: 60943, dtype: object

# %%
df.Element [0]
# Out:
# 'Total Population - Both sexes'

# %%
chosen_columns = df[['Y2017', 'Area']]
grouped_data = chosen_columns.groupby('Area')['Y2017'].sum().reset_index()
seventh_lowest_sum = grouped_data.sort_values(by='Y2017').iloc[6]
area_with_seventh_lowest_sum = seventh_lowest_sum['Area']
print(f"The Area with the 7th lowest sum in 2017 is: {area_with_seventh_lowest_sum}")
# Out:
# The Area with the 7th lowest sum in 2017 is: Guinea-Bissau

# %%
chosen_columns = df[['Y2017', 'Area']]
grouped_data = chosen_columns.groupby('Area')['Y2017'].sum()
area_with_highest_sum = grouped_data.idxmax()
area_with_seventh_lowest_sum = seventh_lowest_sum['Area']
print(f"The area with the highest sum in 2017 is: {area_with_highest_sum}")
# Out:
# The area with the highest sum in 2017 is: Nigeria

# %%
unique_countries = set(df['Area'])
total_unique_countries = len(unique_countries)
print (total_unique_countries)
# Out:
# 49

# %%
correlations = df.drop('Element Code', axis=1).apply(lambda x: df['Element Code'].corr(x))
year_with_least_correlation = correlations.idxmin()

print(f"The year with the least correlation with 'Element Code' is: {year_with_least_correlation}")
